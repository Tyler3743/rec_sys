# %%
import pandas as pd
import numpy as np

# %%
movie=pd.read_csv('movies-new.csv')

# %%
movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movie.shape

# %%
genre=set()
for i in movie['genres']:
    for j in i.split('|'):
        genre.add(j)

# %%
print(genre)
# Out:
# {'Adventure', 'Crime', 'Animation', 'Drama', 'Mystery', 'Thriller', 'Sci-Fi', 'War', '(no genres listed)', 'Musical', 'Western', 'Documentary', 'Film-Noir', 'Comedy', 'IMAX', 'Fantasy', 'Action', 'Horror', 'Children', 'Romance'}

# %%
movie=movie[movie['genres']!='(no genres listed)']

# %%
movie.shape
# Out:
# (9708, 3)
